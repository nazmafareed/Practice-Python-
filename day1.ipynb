# %% [markdown]
# 1. Area of Circle

# %%
import math 
r = float(input("Enter radius : "))
area  = math.pi * r**2
print("Area of a  circle with radius", r, "is :", area)
# Out:
# Area of a  circle with radius 1.1 is : 3.8013271108436504

# %% [markdown]
# 2. Accept First and Last Name

# %%
first_name = input("Enter first naem : ")
last_name = input("Enter last name :")
print(first_name , " ", last_name)
# Out:
# zia   mughal

# %% [markdown]
# 3. Display first and last colors from list

# %%
color_list = ["Red", "Green", "White" , "Black"]
print("The first color name store is list is : ",color_list[0])
print("The last color name store is list is : ",color_list[-1])
# Out:
# The first color name store is list is :  Red
# The last color name store is list is :  Black

# %% [markdown]
# 4. Compute Value of  n + nn + nnn

# %%
n = int(input("Enter a number : "))

result = n + int(str(n)*2) + int(str(n)*3)
print("The result is : ", result)
# Out:
# The result is :  615

# %% [markdown]
# 5. Number of Days Between Two Dates

# %%
from datetime import date
date1 = date(2024, 7, 1)
date2 = date(2024, 12, 25)

delta = date2 - date1
print("Number of days between", date1, "and", date2, "is", delta.days)
# Out:
# Number of days between 2024-07-01 and 2024-12-25 is 177

# %% [markdown]
# 7. Difference Between Given Number and 17

# %%
num = int(input("Enter a number: "))

if num > 17:
    print(2 * abs(num - 17))
else:
    print(17 - num)
# Out:
# 2

# %% [markdown]
# 8. Write a Python program to check whether a given number is within 100 of 1000 or 2000.

# %%
num = int(input("Enter a number :"))
if abs(num - 1000) <= 100:
    print("True")
elif abs(num - 2000) <= 100:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# 9. Sum of Three Numbers (Triple if All Equal)

# %%
a = int(input("Enter first number : "))
b = int(input("Enter second number : "))
c = int(input("Enter third number : "))

total = a + b + c 

if a==b==c :
    print(total * 3)
else :
    print(total)
# Out:
# 18

# %% [markdown]
# 10. Check Whether a Letter is a Vowel

# %%
letter = input("Enter a letter : ").lower()
if letter in ['a', 'e', 'i', 'o', 'u']:
    print(letter, "is a vowel")
else:
    print(letter, "is a consonant")

# %%
print("Hellow world")
# Out:
# Hellow world

# %%
print("Streak bachao")
# Out:
# Streak bachao

# %%
def mult():
    x = 5
    y = 10
    z = x * y
    print("The multiplication of", x, "and", y, "is :", z)

# %% [markdown]
# Program to Check Palindrome Number

# %%
num = input("Enter a number: ")

if num == num[::-1]:
    print("Palindrome number")
else:
    print("Not a palindrome")
# Out:
# Not a palindrome

# %% [markdown]
# Find Sum of First N Natural Numbers

# %%
n = int(input("Enter value of n: "))
sum = 0

for i in range(1, n + 1):
    sum += i

print("Sum =", sum)
# Out:
# Sum = 946

# %% [markdown]
# Print Table of a Number

# %%
num = int(input("Enter a number: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# 54 x 1 = 54
# 54 x 2 = 108
# 54 x 3 = 162
# 54 x 4 = 216
# 54 x 5 = 270
# 54 x 6 = 324
# 54 x 7 = 378
# 54 x 8 = 432
# 54 x 9 = 486
# 54 x 10 = 540

# %% [markdown]
# Program to Check Prime Number

# %%
num = int(input("Enter a number: "))
count = 0

for i in range(1, num + 1):
    if num % i == 0:
        count += 1

if count == 2:
    print("Prime number")
else:
    print("Not a prime number")
# Out:
# Not a prime number
